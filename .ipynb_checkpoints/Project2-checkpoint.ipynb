# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import numpy as np

# %%
#Pull data from csv file- traffic camera locations
csv_file = "../Desktop/ETL_Project/traffic-cameras-1.csv"
traffic_cameras_df = pd.read_csv(csv_file)
traffic_cameras_df["Longitude"] = traffic_cameras_df["Longitude"].map("{:.3f}".format)
traffic_cameras_df["Latitude"] = traffic_cameras_df["Latitude"].map("{:.3f}".format)
traffic_cameras_df.head()
# Out:
#    Camera ID Camera Manufacturer Turn on Date ATD Location ID  \
# 0         68               Sarix          NaN    LOC16-000180
# 1          1               Sarix   11/18/2016    LOC16-005090
# 2          3               Sarix   12/20/2016    LOC16-004915
# 3          4    Spectra Enhanced   11/30/2016    LOC16-003630
# 4          2    Spectra Enhanced   11/08/2016    LOC16-000805
#
#    Primary St Segment ID  Cross St Segment ID  \
# 0              2017636.0            2017637.0
# 1              3268115.0                  NaN
# 2              5102830.0            2029964.0
# 3              2040576.0            2020020.0
# 4              2018548.0            2018299.0
#
#                            Landmark Signal Engineer Area Council District  \
# 0                               NaN              CENTRAL                9
# 1  Little Walnut Creek Library, HEB            NORTHEAST                4
# 2                               NaN            NORTHWEST                6
# 3                               NaN              CENTRAL               10
# 4                               NaN            NORTHEAST              3,1
#
#    JURISDICTION                    ...                     CROSS_ST_AKA  \
# 0           NaN                    ...                              NaN
# 1           NaN                    ...                              NaN
# 2           NaN                    ...                              NaN
# 3           NaN                    ...                              NaN
# 4           NaN                    ...                              NaN
#
#   Cross Street Block PRIMARY_ST_AKA                   Location IP Comm Status  \
# 0              401.0            NaN  (30.2837963, -97.7419052)        OFFLINE
# 1                NaN            NaN  (30.3636856, -97.6981583)        OFFLINE
# 2            10001.0            NaN  (30.4819565, -97.7895737)        OFFLINE
# 3             3400.0            NaN      (30.31354, -97.76716)        OFFLINE
# 4             3300.0            NaN  (30.2735558, -97.6979065)         ONLINE
#
#    IP Comm Status Date and Time  Longitude Latitude Published Screenshots  \
# 0  06/23/2017 01:59:00 AM +0000    -97.742   30.284                   NaN
# 1  10/02/2017 05:18:00 PM +0000    -97.698   30.364                   NaN
# 2  05/11/2017 05:00:00 AM +0000    -97.790   30.482                   NaN
# 3  05/11/2017 05:00:00 AM +0000    -97.767   30.314                   NaN
# 4  10/02/2017 08:46:00 PM +0000    -97.698   30.274                   NaN
#
#                           Screenshot Address
# 0  http://162.89.4.145/CCTVImages/CCTV68.jpg
# 1   http://162.89.4.145/CCTVImages/CCTV1.jpg
# 2   http://162.89.4.145/CCTVImages/CCTV3.jpg
# 3   http://162.89.4.145/CCTVImages/CCTV4.jpg
# 4   http://162.89.4.145/CCTVImages/CCTV2.jpg
#
# [5 rows x 28 columns]

# %%
cam_columns = ["Camera ID", "Turn on Date", "Location Name", "Location","Longitude","Latitude"]
new_traffic_cameras_df = traffic_cameras_df[cam_columns].copy()
new_traffic_cameras_df = new_traffic_cameras_df.rename(columns={"Camera ID":"Camera_ID","Turn on Date":"Turn_on_Date","Location Name":"Location_Name"})
new_traffic_cameras_df = new_traffic_cameras_df.set_index(["Camera_ID"])
new_traffic_cameras_df.head()
# Out:
#           Turn_on_Date                                      Location_Name  \
# Camera_ID
# 68                 NaN                             GUADALUPE ST / 21ST ST
# 1           11/18/2016  830 BLK W RUNDBERG LN (Little Walnut Creek Lib...
# 3           12/20/2016                   STAKED PLAINS DR / LAKELINE BLVD
# 4           11/30/2016                                 35TH ST / PECOS ST
# 2           11/08/2016                      AIRPORT BLVD / OAK SPRINGS DR
#
#                             Location Longitude Latitude
# Camera_ID
# 68         (30.2837963, -97.7419052)   -97.742   30.284
# 1          (30.3636856, -97.6981583)   -97.698   30.364
# 3          (30.4819565, -97.7895737)   -97.790   30.482
# 4              (30.31354, -97.76716)   -97.767   30.314
# 2          (30.2735558, -97.6979065)   -97.698   30.274

# %%
new_traffic_cameras_df.dtypes
# Out:
# Turn_on_Date     object
# Location_Name    object
# Location         object
# Longitude        object
# Latitude         object
# dtype: object

# %%
#Pull data from csv file- traffic incidents
csv_file = "../Desktop/ETL_project/Real-Time_Traffic_Incident_Reports.csv"
traffic_incidents_df = pd.read_csv(csv_file)
traffic_incidents_df["Longitude"] = traffic_incidents_df["Longitude"].map("{:.3f}".format)
traffic_incidents_df["Latitude"] = traffic_incidents_df["Latitude"].str.replace(',','').astype(np.float64)
traffic_incidents_df["Latitude"] = traffic_incidents_df["Latitude"].map("{:.3f}".format)
traffic_incidents_df.dropna()
traffic_incidents_df.head()
# Out:
#                                    Traffic Report ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  2664C206999E7419517EE39E177797576A52201B_15381...
# 2  5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_15438...
# 3  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 4  5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_15521...
#
#                  Published Date  Issue Reported                Location  \
# 0  06/13/2018 06:35:59 AM +0000   Crash Service  (30.283797,-97.741906)
# 1  09/29/2018 12:52:58 AM +0000  Traffic Hazard  (30.380525,-97.737873)
# 2  12/03/2018 05:49:02 PM +0000   Crash Service  (30.278372,-97.671971)
# 3  06/13/2018 10:15:36 AM +0000  Traffic Hazard  (30.339593,-97.700963)
# 4  03/09/2019 03:07:05 PM +0000  Traffic Hazard   (30.201332,-97.77585)
#
#   Latitude Longitude                         Address    Status  \
# 0   30.284   -97.742        W 21ST ST & GUADALUPE ST  ARCHIVED
# 1   30.381   -97.738  0 Mopac Sb To Research Sb Ramp  ARCHIVED
# 2   30.278   -97.672           5800 Techni Center Dr  ARCHIVED
# 3   30.340   -97.701        400-717 E ANDERSON LN EB  ARCHIVED
# 4   30.201   -97.776             6000 S Congress Ave  ARCHIVED
#
#                     Status Date
# 0  06/13/2018 09:00:03 AM +0000
# 1  09/29/2018 01:35:03 AM +0000
# 2  12/03/2018 06:30:03 PM +0000
# 3  06/13/2018 11:20:03 AM +0000
# 4  03/09/2019 03:15:04 PM +0000

# %%
incident_columns = ["Traffic Report ID","Published Date", "Issue Reported","Location", "Longitude","Latitude", "Address"]
new_traffic_incidents_df = traffic_incidents_df[incident_columns].copy()
new_traffic_incidents_df.dropna()
new_traffic_incidents_df = new_traffic_incidents_df.rename(columns={"Traffic Report ID":"Traffic_Report_ID","Published Date":"Published_Date","Issue Reported":"Issue_Reported"})
new_traffic_incidents_df = new_traffic_incidents_df.set_index(["Traffic_Report_ID"])
new_traffic_incidents_df.head()
# Out:
#                                                                   Published_Date  \
# Traffic_Report_ID
# C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_152887...  06/13/2018 06:35:59 AM +0000
# 2664C206999E7419517EE39E177797576A52201B_153818...  09/29/2018 12:52:58 AM +0000
# 5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_154385...  12/03/2018 05:49:02 PM +0000
# 6B20382196FB454E9FD06A33E60142902A2F0706_152888...  06/13/2018 10:15:36 AM +0000
# 5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_155214...  03/09/2019 03:07:05 PM +0000
#
#                                                     Issue_Reported  \
# Traffic_Report_ID
# C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_152887...   Crash Service
# 2664C206999E7419517EE39E177797576A52201B_153818...  Traffic Hazard
# 5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_154385...   Crash Service
# 6B20382196FB454E9FD06A33E60142902A2F0706_152888...  Traffic Hazard
# 5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_155214...  Traffic Hazard
#
#                                                                   Location  \
# Traffic_Report_ID
# C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_152887...  (30.283797,-97.741906)
# 2664C206999E7419517EE39E177797576A52201B_153818...  (30.380525,-97.737873)
# 5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_154385...  (30.278372,-97.671971)
# 6B20382196FB454E9FD06A33E60142902A2F0706_152888...  (30.339593,-97.700963)
# 5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_155214...   (30.201332,-97.77585)
#
#                                                    Longitude Latitude  \
# Traffic_Report_ID
# C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_152887...   -97.742   30.284
# 2664C206999E7419517EE39E177797576A52201B_153818...   -97.738   30.381
# 5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_154385...   -97.672   30.278
# 6B20382196FB454E9FD06A33E60142902A2F0706_152888...   -97.701   30.340
# 5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_155214...   -97.776   30.201
#
#                                                                            Address
# Traffic_Report_ID
# C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_152887...        W 21ST ST & GUADALUPE ST
# 2664C206999E7419517EE39E177797576A52201B_153818...  0 Mopac Sb To Research Sb Ramp
# 5BB246A3223A89C7FB9B2EED9A2EBDA82141406D_154385...           5800 Techni Center Dr
# 6B20382196FB454E9FD06A33E60142902A2F0706_152888...        400-717 E ANDERSON LN EB
# 5CB97D4F03F917B5DCE1B3F99B1EB647FF58DA7F_155214...             6000 S Congress Ave

# %%
new_traffic_incidents_df.dtypes
# Out:
# Published_Date    object
# Issue_Reported    object
# Location          object
# Longitude         object
# Latitude          object
# Address           object
# dtype: object

# %%
connection_string = "root:Ikigai12@localhost/ETL_db"
engine = create_engine(f'mysql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['traffic_cameras', 'traffic_incidents']

# %%
#new_traffic_cameras_df.to_sql(name='traffic_cameras', con=engine, if_exists='append', index=True)
new_traffic_incidents_df.to_sql(name='traffic_incidents', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     228             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 229                 rows += self.execute(sql + postfix)
#     230                 sql = bytearray(prefix)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# DataError: (1265, "Data truncated for column 'Longitude' at row 1309")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-158-157ff0586b5d> in <module>
#       1 #new_traffic_cameras_df.to_sql(name='traffic_cameras', con=engine, if_exists='append', index=True)
# ----> 2 new_traffic_incidents_df.to_sql(name='traffic_incidents', con=engine, if_exists='append', index=True)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246         except BaseException as e:
#    1247             self._handle_dbapi_exception(
# -> 1248                 e, statement, parameters, cursor, context
#    1249             )
#    1250
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1464                 util.raise_from_cause(newraise, exc_info)
#    1465             elif should_wrap:
# -> 1466                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1467             else:
#    1468                 util.reraise(*exc_info)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     381     exc_type, exc_value, exc_tb = exc_info
#     382     cause = exc_value if exc_value is not exception else None
# --> 383     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     384
#     385
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     126             value.__cause__ = cause
#     127         if value.__traceback__ is not tb:
# --> 128             raise value.with_traceback(tb)
#     129         raise value
#     130
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1222                 if not evt_handled:
#    1223                     self.dialect.do_executemany(
# -> 1224                         cursor, statement, parameters, context
#    1225                     )
#    1226             elif not parameters and context.no_parameters:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     130
#     131     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 132         rowcount = cursor.executemany(statement, parameters)
#     133         if context is not None:
#     134             context._rowcount = rowcount
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     227                     v = v.encode(encoding, 'surrogateescape')
#     228             if len(sql) + len(v) + len(postfix) + 1 > max_stmt_length:
# --> 229                 rows += self.execute(sql + postfix)
#     230                 sql = bytearray(prefix)
#     231             else:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /anaconda3/envs/PythonData/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1265, "Data truncated for column 'Longitude' at row 1309")
# [SQL: INSERT INTO traffic_incidents (`Traffic_Report_ID`, `Published_Date`, `Issue_Reported`, `Location`, `Longitude`, `Latitude`, `Address`) VALUES (%(Traffic_Report_ID)s, %(Published_Date)s, %(Issue_Reported)s, %(Location)s, %(Longitude)s, %(Latitude)s, %(Address)s)]
# [parameters: ({'Traffic_Report_ID': 'C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_1528871759', 'Published_Date': '06/13/2018 06:35:59 AM +0000', 'Issue_Reported': 'Crash Service', 'Location': '(30.283797,-97.741906)', 'Longitude': '-97.742', 'Latitude': '30.284', 'Address': 'W 21ST ST & GUADALUPE ST'}, {'Traffic_Report_ID': '2664C206999E7419517EE39E177797576A52201B_1538182378', 'Published